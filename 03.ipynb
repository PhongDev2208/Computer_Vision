# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/PhongIT/Pictures/dog.jfif'

# %%
# Đọc ảnh 
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
# Kích thước ban đầu:
print(img.size)
# Out:
# (225, 225)

# %%
# Thay đổi kích thước
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Task: lưu ảnh
dirOut = 'C:/Users/PhongIT/Documents/TGMT/images'
new_img_path = dirOut + '/meoResized.JPG'
img.save(new_img_path)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Task: lưu ảnh
dirOut = 'C:/Users/PhongIT/Documents/TGMT/images'
new_img_path = dirOut + '/meoThumbnaild.JPG'
img.save(new_img_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x50>
